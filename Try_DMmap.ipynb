# %%
import matplotlib.pyplot as plt
import os
import numpy as np
import healpy as hp
from tqdm import *

import dm_map
from dm_map import DM_map

# %%
Map = DM_map()

# %%
# %%time
provaSimple = Map.DarkMap(32, 'NFW', 24, 20, 1, 400, 0.05)
# Out:
# CPU times: user 17min 14s, sys: 7.8 s, total: 17min 21s
# Wall time: 18min 33s

# %%
hp.mollview(provaSimple,title='NFW - Decay')
